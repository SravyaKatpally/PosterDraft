# %%
import requests
from bs4 import BeautifulSoup
import re
#import urllib.request

#Used headers/agent as the request timed out and asking for agent. Using following code you can fake the agent.

mainDict ={}

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
Hydresponse = requests.get("https://www.zomato.com/hyderabad/great-food-no-bull",headers=headers)

Hydcontent = Hydresponse.content
Hydsoup = BeautifulSoup(Hydcontent,"html.parser")
#print(Hydsoup)


top_rest = Hydsoup.find_all("div",attrs={"class": "bb0 collections-grid col-l-16"})
#print(top_rest)
list_tr = top_rest[0].find_all("div",attrs={"class": "col-s-8 col-l-1by3"})
list_rest =[]
mydict ={}
for i in range(0,70):    
    dataframe =[]
    body = Hydsoup.findAll("div",{"class": "ads-res-snippet-rating-large"})
    body1  = Hydsoup.findAll("div",{"class":"res_title"})
    b =[]
    b = ((body1[i].text.replace('\n', '')).strip())
    a=[]
    a = ((body[i].text.replace('\n', '')).strip())
    dataframe.append(b)
    dataframe.append((a))
    mydict[b] = a
    list_rest.append(dataframe)
list1 = sorted(list_rest)
list1 = list1[0:70]
sorteddict={}

for key in sorted(mydict.keys())[:70]:
    main ='ab'"'"'s - absolute barbecues'
    #print('ll ', main)
    #print(key.lower())
    if(key.lower()==main):
        d = key    
        e = mydict[key]
        sorteddict[d] = e
print(sorteddict)
print(e)
mainDict['Hyderabad'] = e
print('ll:', mainDict)
# Out:
# {"AB's - Absolute Barbecues": '4.5'}
# 4.5
# ll: {'Hyderabad': '4.5'}
#                        Restaurants Rating
# 0   3B's - Buddies, Bar & Barbecue    4.6
# 1        AB's - Absolute Barbecues    4.5
# 2      Adaa - Taj Falaknuma Palace    4.8
# 3                           B-Dubs    4.5
# 4                  Barbeque Nation    4.5
# 5                       Cafe Bahar    4.7
# 6           Cafe Niloufer & Bakers    4.5
# 7                       Carpe Diem    4.6
# 8     Chili's American Grill & Bar    4.6
# 9                        Churrolto    4.5
# 10               Coconut Juice Bar    4.7
# 11                      Coffee Cup    4.5
# 12                           Conçu    4.7
# 13           Dhaba Estd 1986 Delhi    4.7
# 14            Dialogue in the Dark    4.6
# 15                  Essence Fusion    4.5
# 16                        Euphoria    4.5
# 17                         Exotica    4.8
# 18            Fat Pigeon - Bar Hop    4.7
# 19                 Feu Dessert Bar    4.5
# 20                        Flechazo    4.6
# 21        Flying Spaghetti Monster    4.5
# 22                   Frozen Desert    4.9
# 23       Ghrelin Cafe & Patisserie    4.5
# 24                 Gourmet Baklava    4.6
# 25     Haji Ali Fresh Fruit Juices    4.5
# 26                  Hard Rock Cafe    4.8
# 27   Jewel of Nizam - The Minar...    4.5
# 28            Kakatiya Deluxe Mess    4.5
# 29                  Karachi Bakery    4.5
# ..                             ...    ...
# 40                    Olive Bistro    4.5
# 41                          Onesta    4.7
# 42                          Palato    4.7
# 43                        Paradise    4.6
# 44                  Piccolo Gelato    4.9
# 45                       Pizza Den    4.5
# 46                  Prost Brew Pub    4.6
# 47                  Resign Sky Bar    4.5
# 48               Santè Spa Cuisine    4.7
# 49    Seasonal Tastes - The Westin    4.5
# 50     Shalimar Tiffins and Snacks    4.6
# 51            SodaBottleOpenerWala    4.7
# 52          Sofrehh Persian Bistro    4.6
# 53         Stikstof Ice-Cream Cafe    4.5
# 54             Subbayya Gari Hotel    4.6
# 55                   Subhan Bakery    4.5
# 56                          Talasa    NEW
# 57                           Tatva    4.6
# 58          The Belgian Waffle Co.    4.5
# 59               The Blenders Cafe    4.7
# 60              The Chocolate Room    4.5
# 61           The Fisherman's Wharf    4.6
# 62                  The Indi Grill    4.6
# 63       The Roastery Coffee House    4.5
# 64                        Thinespo    4.7
# 65     Tre-Forni Restaurant and...    4.5
# 66             Trio- La Patisserie    4.6
# 67                Vac's Patisserie    4.5
# 68                      Van Lavino    4.6
# 69                  Zero40 Brewing    4.7
#
# [70 rows x 2 columns]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
Chennairesponse = requests.get("https://www.zomato.com/chennai/great-food-no-bull",headers=headers)


Ccontent = Chennairesponse.content
Csoup = BeautifulSoup(Ccontent,"html.parser")
#print(Csoup)

top_rest = Csoup.find_all("div",attrs={"class": "bb0 collections-grid col-l-16"})
#print(top_rest)
list_tr = top_rest[0].find_all("div",attrs={"class": "col-s-8 col-l-1by3"})
list_rest =[]
mydict ={}
for i in range(0,68):    
    dataframe =[]
   
    body = Csoup.findAll("div",{"class": "ads-res-snippet-rating-large"})
    body1  = Csoup.findAll("div",{"class":"res_title"})
    b =[]
    b = ((body1[i].text.replace('\n', '')).strip())
    a=[]
    a = ((body[i].text.replace('\n', '')).strip())
    dataframe.append(b)
    dataframe.append((a))
    
    mydict[b] = a
    list_rest.append(dataframe)
    
#from collections import defaultdict
#data_dict = defaultdict(list)
#print(mydict)

list1 = sorted(list_rest)
list1 = list1[0:70]
#print('ll :', mydict)
#print(list_rest)
sorteddict={}
#print(sorteddict)


for key in sorted(mydict.keys())[:70]:
    main ='ab'"'"'s - absolute barbecues'
    #print('ll ', main)
    #print(key.lower())
    if(key.lower()==main.lower()):
        d = key    
        e = mydict[key]
        sorteddict[d] = e
print(sorteddict)
print(e)
mainDict['Chennai'] = e
print('ll:', mainDict)
# Out:
# {"AB's - Absolute Barbecues": '4.6'}
# 4.6
# ll: {'Hyderabad': '4.5', 'Chennai': '4.6'}
#                        Restaurants Rating
# 0   3B's - Buddies, Bar & Barbecue    4.5
# 1        AB's - Absolute Barbecues    4.6
# 2             Alchemy Bar & Lounge    4.6
# 3   Amadora Gourmet Ice Cream &...    4.5
# 4   Asia Kitchen by Mainland China    4.7
# 5                      Axpress BBQ    4.6
# 6                  Barbeque Nation    4.5
# 7               Basil With A Twist    4.6
# 8      Bazaar - All Day Diner -...    4.6
# 9                          Bhangra    4.6
# 10                 Blind Ch3mistry    4.5
# 11                    Bombay Kulfi    4.6
# 12                  Brownie Heaven    4.5
# 13                         Chianti    4.5
# 14    Chili's American Grill & Bar    4.6
# 15     China XO - The Leela Palace    4.5
# 16             Cleo's Grill & Cafe    4.5
# 17                  Coal Barbecues    4.5
# 18       Dakshin - Crowne Plaza...    4.5
# 19                   Delhi Highway    4.6
# 20           Dhaba Estd 1986 Delhi    4.5
# 21            Dialogue In The Dark    4.7
# 22     East Coast at Madras Square    4.6
# 23                  Eating Circles    4.5
# 24   Fabelle Chocolate Boutique...    4.5
# 25            Fresh Baked Goodness    4.8
# 26                 Fusilli Reasons    4.5
# 27            Gossip Fusion Bistro    4.7
# 28       Grill Box - Unlimited BBQ    4.6
# 29                           Hamsa    4.7
# ..                             ...    ...
# 38                           Mezze    4.6
# 39     Momo Sa-Khang by Kailash...    4.5
# 40                    Nasi And Mee    4.6
# 41                          Onesta    4.6
# 42                       Palmshore    4.5
# 43     Pan Asian - ITC Grand Chola    4.6
# 44                        Patissez    4.5
# 45           Prems Graama Bhojanam    4.7
# 46                   Pumpkin Tales    4.5
# 47                    Rayar's Mess    4.5
# 48        Sangeetha Veg Restaurant    4.5
# 49               Sante Spa Cuisine    4.5
# 50                          Shakos    4.5
# 51  Shmoozie's Hand-Crafted Ice...    4.5
# 52                    Shree Mithai    4.5
# 53             Sigree Global Grill    4.5
# 54                         Soy Soi    4.5
# 55                       SpiceKlub    4.8
# 56                 The Black Pearl    4.7
# 57                      The Marina    4.6
# 58    The Melting Pot: Market Cafe    4.5
# 59      The Moon And Sixpence -...    4.8
# 60               The Sandwich Shop    4.6
# 61   VB Signature - Progressive...    4.7
# 62          Va Pho - Asian Canteen    4.5
# 63                       Waf O'Bel    4.6
# 64                   Welcome Hotel    4.6
# 65                        Wok Monk    4.9
# 66                   Writer's Cafe    4.7
# 67            Yaa Mohideen Biryani    4.6
#
# [68 rows x 2 columns]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
Bangloreresponse = requests.get("https://www.zomato.com/bangalore/great-food-no-bull",headers=headers)


Bcontent = Bangloreresponse.content
Bsoup = BeautifulSoup(Bcontent,"html.parser")
#print(Bsoup)

top_rest = Bsoup.find_all("div",attrs={"class": "bb0 collections-grid col-l-16"})
#print(top_rest)
list_tr = top_rest[0].find_all("div",attrs={"class": "col-s-8 col-l-1by3"})
list_rest =[]
mydict ={}
for i in range(0,70):    
    dataframe =[]
   
    body = Bsoup.findAll("div",{"class": "ads-res-snippet-rating-large"})
    body1  = Bsoup.findAll("div",{"class":"res_title"})
    b =[]
    b = ((body1[i].text.replace('\n', '')).strip())
    a=[]
    a = ((body[i].text.replace('\n', '')).strip())
    dataframe.append(b)
    dataframe.append((a))
    
    mydict[b] = a
    list_rest.append(dataframe)
    
#from collections import defaultdict
#data_dict = defaultdict(list)
#print(mydict)

list1 = sorted(list_rest)
list1 = list1[0:70]
#print('ll :', mydict)
#print(list_rest)
sorteddict={}
#print(sorteddict)


for key in sorted(mydict.keys())[:70]:
    main ='ab'"'"'s - absolute barbecues'
    #print('ll ', main)
    #print(key.lower())
    if(key.lower()==main.lower()):
        d = key    
        e = mydict[key]
        sorteddict[d] = e
print(sorteddict)
print(e)
mainDict['Banglore'] = e
#print('ll:', mainDict)
# Out:
# {"AB's - Absolute Barbecues": '4.6'}
# 4.6
# ll: {'Hyderabad': '4.5', 'Chennai': '4.6', 'Banglore': '4.6'}
#                        Restaurants Rating
# 0        AB's - Absolute Barbecues    4.6
# 1     Alba - JW Marriott Bengaluru    4.6
# 2    Arena - Artisanal Brewkitchen    4.5
# 3                    Arogya Ahaara    4.6
# 4         Barbecue by Punjab Grill    4.5
# 5                          BelgYum    4.6
# 6                       Black Deer    4.5
# 7                          Bologna    4.8
# 8                      Bombay Adda    4.5
# 9         Brew and Barbeque - A...    4.5
# 10                Buff Buffet Buff    4.5
# 11                     Burma Burma    4.5
# 12     Byg Brewski Brewing Company    4.6
# 13                       Chai Days    4.5
# 14    Chili's American Grill & Bar    4.6
# 15         Dhaba - Estd 1986 Delhi    4.6
# 16                          Dhuaan    4.5
# 17                    Dock Frost'd    4.6
# 18                    Dyu Art Cafe    4.5
# 19   Fabelle Chocolate Boutique...    4.5
# 20      Fenny's Lounge And Kitchen    4.5
# 21                        Flechazo    4.5
# 22                       Food Coma    4.8
# 23                        Galito's    4.5
# 24                Gilly's Restobar    4.6
# 25                   Hakuna Matata    4.5
# 26                      Here & Now    4.5
# 27               Inntense Restobar    4.5
# 28                         Lavonne    4.5
# 29    Levitate Brewery and Kitchen    4.5
# ..                             ...    ...
# 40  Republic Of Noodles - Lemon...    4.5
# 41                   Rolls & Bowls    4.7
# 42                           Roots    4.5
# 43               Santé Spa Cuisine    4.8
# 44                        Sea Rock    4.5
# 45                   Shakes Theory    4.5
# 46                    ShakesBierre    4.6
# 47                    Sharief Bhai    4.6
# 48       Sidewalk - The Garden Bar    4.9
# 49                Smoke House Deli    4.5
# 50                          Social    4.5
# 51                          Stoner    4.6
# 52                         Stories    4.5
# 53      Stories - The Brew Chapter    4.7
# 54                  TBC Sky Lounge    4.6
# 55                    Taaza Thindi    4.5
# 56                           Taiki    4.5
# 57                The Big Barbeque    4.7
# 58                  The Globe Grub    4.5
# 59       The Hole in the Wall Cafe    4.6
# 60                      The Pallet    4.5
# 61                 The Permit Room    4.5
# 62                The Pizza Bakery    4.5
# 63                        Truffles    4.6
# 64                     Vanilla Sky    4.5
# 65                    Veena Stores    4.7
# 66                      Via Milano    4.5
# 67                   XOOX Brewmill    4.5
# 68                        Yauatcha    4.6
# 69                         eat.fit    4.6
#
# [70 rows x 2 columns]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
Puneresponse = requests.get("https://www.zomato.com/pune/great-food-no-bull",headers=headers)


Pcontent = Puneresponse.content
Psoup = BeautifulSoup(Pcontent,"html.parser")
#print(Psoup)

top_rest = Psoup.find_all("div",attrs={"class": "bb0 collections-grid col-l-16"})
#print(top_rest)
list_tr = top_rest[0].find_all("div",attrs={"class": "col-s-8 col-l-1by3"})
list_rest =[]
mydict ={}
for i in range(0,90):    
    dataframe =[]
   
    body = Psoup.findAll("div",{"class": "ads-res-snippet-rating-large"})
    body1  = Psoup.findAll("div",{"class":"res_title"})
    b =[]
    b = ((body1[i].text.replace('\n', '')).strip())
    a=[]
    a = ((body[i].text.replace('\n', '')).strip())
    dataframe.append(b)
    dataframe.append((a))
    
    mydict[b] = a
    list_rest.append(dataframe)
    
#from collections import defaultdict
#data_dict = defaultdict(list)
#print(mydict)

list1 = sorted(list_rest)
list1 = list1[0:70]
#print('ll :', mydict)
#print(list_rest)
sorteddict={}
#print(sorteddict)


for key in sorted(mydict.keys())[:70]:
    main ='ab'"'"'s - absolute barbecues'
    #print('ll ', main)
    #print(key.lower())
    if(key.lower()==main.lower()):
        d = key    
        e = mydict[key]
        sorteddict[d] = e
print(sorteddict)
print(e)
mainDict['Pune'] = e
print('ll:', mainDict)


import pandas as pd
#Creating a dataframe object from listoftuples
df = pd.DataFrame(list1, columns = ['Restaurants', 'Rating'])

from IPython.display import display
df
# Out:
# {"AB's - Absolute Barbecues": '4.6'}
# 4.6
# ll: {'Hyderabad': '4.5', 'Chennai': '4.6', 'Banglore': '4.6', 'Pune': '4.6'}
#                        Restaurants Rating
# 0                    1441 Pizzeria    4.6
# 1        AB's - Absolute Barbecues    4.6
# 2                    Aaoji Khhaoji    4.9
# 3      Aaoji Khhaoji - The Veg Bar    4.6
# 4                     Agent Jack's    4.5
# 5                      Anda Ground    4.7
# 6                        Anna Idli    4.5
# 7          Arbour Kitchen | Drinks    4.5
# 8                         Autobahn    4.7
# 9                         BarBerry    4.5
# 10             Baraza Bars & Bites    4.5
# 11                  Barbeque Ville    4.5
# 12                       Barometer    4.6
# 13        Bipin Snacks & Juice Bar    4.5
# 14                      Blue Water    4.5
# 15         Boteco - Restaurante...    4.5
# 16                          Burger    4.7
# 17                       Cafe 1730    4.6
# 18                        Cafe Goa    4.7
# 19                     Cafe Paashh    4.9
# 20    Chili's American Grill & Bar    4.7
# 21       Chitale Bandhu Mithaiwale    4.5
# 22                    Crazy Cheesy    4.5
# 23                         Darshan    4.7
# 24               Drink Your Selfie    4.8
# 25        Eternia Rooftop Resto...    4.6
# 26                        Flechazo    4.6
# 27                 Flying Duck Co.    4.6
# 28                        Forennte    4.9
# 29                            Gong    4.8
# ..                             ...    ...
# 40          Level 5 Bistro and Bar    4.5
# 41                         Levit 8    4.5
# 42                            Loft    4.7
# 43                    Malaka Spice    4.5
# 44               Mineority By Saby    4.5
# 45                 Mohan Ice Cream    4.9
# 46                  Momo's Corrner    4.5
# 47        Mr Rabbit's Bar & Burrow    4.6
# 48                     Nine Square    4.8
# 49                   Origin Bistro    4.6
# 50     Over The Top - Radisson Blu    4.5
# 51       Paasha - JW Marriott Pune    4.6
# 52        Pagdandi Books Chai Cafe    4.5
# 53             Peter's Momo Center    4.8
# 54                      Pop Tate's    4.8
# 55                       RocoMamas    4.5
# 56                     Royal China    4.7
# 57               Santè Spa Cuisine    4.9
# 58                      Savya Rasa    4.5
# 59                 Sentosa Highway    4.7
# 60         Sentosa MultiCuisine...    4.5
# 61                    Shiv Kailash    4.5
# 62                        Shizusan    4.5
# 63            Sorted. Delicatessen    4.5
# 64  Spice Kitchen - JW Marriott...    4.5
# 65                Starbucks Coffee    4.9
# 66         Supreme Sandwich Corner    4.5
# 67                    Sweet Mantra    4.5
# 68                    The Barkhana    4.6
# 69                  The Blue Plate    4.5
#
# [70 rows x 2 columns]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
Puneresponse = requests.get("https://www.zomato.com/ncr/great-food-no-bull",headers=headers)


Pcontent = Puneresponse.content
Psoup = BeautifulSoup(Pcontent,"html.parser")
#print(Psoup)

top_rest = Psoup.find_all("div",attrs={"class": "bb0 collections-grid col-l-16"})
#print(top_rest)
list_tr = top_rest[0].find_all("div",attrs={"class": "col-s-8 col-l-1by3"})
list_rest =[]
mydict ={}
for i in range(0,90):    
    dataframe =[]
   
    body = Psoup.findAll("div",{"class": "ads-res-snippet-rating-large"})
    body1  = Psoup.findAll("div",{"class":"res_title"})
    b =[]
    b = ((body1[i].text.replace('\n', '')).strip())
    a=[]
    a = ((body[i].text.replace('\n', '')).strip())
    dataframe.append(b)
    dataframe.append((a))
    
    mydict[b] = a
    list_rest.append(dataframe)
    
#from collections import defaultdict
#data_dict = defaultdict(list)
#print(mydict)

list1 = sorted(list_rest)
list1 = list1[0:70]
#print('ll :', mydict)
#print(list_rest)
sorteddict={}
#print(sorteddict)






l =[]

h =[]
x =[]
for key in sorted(mainDict.keys()):
    f=[]
    d = key    
    f.append(d)
    p = mainDict[key]
    f.append(p)
    l.append(f)
    


print(l)

import pandas as pd
#Creating a dataframe object from listoftuples
df = pd.DataFrame(l, columns = ['location', 'Rating'])

from IPython.display import display
df
# Out:
# [['Banglore', '4.6'], ['Chennai', '4.6'], ['Delhi', '4.7'], ['Hyderabad', '4.5'], ['Pune', '4.6']]
#     location Rating
# 0   Banglore    4.6
# 1    Chennai    4.6
# 2      Delhi    4.7
# 3  Hyderabad    4.5
# 4       Pune    4.6

# %%
import matplotlib.pyplot as plt
NUM_VALUES = 5
heights = list(mainDict.values())
#heights = [4.5, 4.6 ,4.7,4.8,4.9]
print(heights)

heights.sort(reverse = True)
plt.bar(range(len(heights)), heights)
plt.title('Ratings')
plt.ylabel('# Restaurants')
keys = sorted(list(mainDict.keys()), reverse =True)
keys.sort(reverse = True, key = lambda x: mainDict[x])
plt.xticks(range(NUM_VALUES), keys[:NUM_VALUES])
#print(keys)
print("AB's ABSOLUTE BARBECUE")
plt.show()

plt.savefig('ratings.png', Transparent = True)
# Out:
# ['4.5', '4.6', '4.6', '4.6', '4.7']
# AB's ABSOLUTE BARBECUE
